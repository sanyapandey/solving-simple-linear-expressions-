# %%
# importing necessary modules
import numpy as np
import os
import cv2
import random
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, ReLU

# defining random seed
np.random.seed(28)

# function to read the training dataset
# we obtain 800 images for each category
def read_data(filename):
    pwd = os.getcwd()
    training = os.path.join(pwd, filename)
    categories = os.listdir(training)
    x = []
    y = []
    kernel = np.ones(shape=(3,3), dtype = np.uint8)
    for category in categories:
        path = os.path.join(training, category)
        files = random.sample(os.listdir(path), 800)
        for file in files:
            temp = 255 - cv2.imread(os.path.join(path, file), 0)
            temp1 = np.zeros(shape = (temp.shape[0] + 10, temp.shape[1] + 10), dtype = np.uint8)
            temp1[5:5+temp.shape[0], 5:5+temp.shape[1]] = temp.copy()
            temp2 = cv2.dilate(temp1.copy(), kernel.copy(), iterations = 1)
            temp2[temp2 >= 10] = 255
            temp2[temp2 < 10] = 0
            x.append(cv2.resize(temp2.copy(), (60, 60)).reshape(60, 60, 1))
            y.append(category)
    x = np.array(x)
    y = np.array(y)
    y[y == "("] = 10
    y[y == ")"] = 11
    y[y == "+"] = 12
    y[y == "-"] = 13
    y[y == "times"] = 14
    y[y == "div"] = 15
    y[y == "0"] = 0
    y[y == "1"] = 1
    y[y == "2"] = 2
    y[y == "3"] = 3
    y[y == "4"] = 4
    y[y == "5"] = 5
    y[y == "6"] = 6
    y[y == "7"] = 7
    y[y == "8"] = 8
    y[y == "9"] = 9
    y = y.astype(int)
    Y = keras.utils.to_categorical(y, 16)
    X = x.astype(float) / 255
    return X, Y

# function to build our CNN model and compile it
def get_model():
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = 5, padding = "same", input_shape=  (60, 60, 1)))
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size = 2))
    model.add(Dropout(0.3))
    model.add(Conv2D(filters = 64, kernel_size = 5, padding = "same"))
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size = 2))
    model.add(Dropout(0.3))
    model.add(Conv2D(filters = 96, kernel_size = 5, padding = "same"))
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size = 2))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(128, activation = "relu"))
    model.add(Dropout(0.3))
    model.add(Dense(16, activation = "softmax"))
    model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return model

# function to train our CNN model
def train_model(model, x_train, y_train, x_test, y_test, batch_size, epochs):
    model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_test, y_test))
    return model

# function to save out CNN model
def save_model(model):
    model.save("19_CNN_MODEL", save_format = "h5")
    return

# function to split our data into train and test to evaluate our CNN model
def split_data(X, Y):
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, shuffle = True)
    return x_train, x_test, y_train, y_test

# main function
def run(filename):
    print("Starting process")
    X, Y = read_data(filename)
    print("Data read successfully")
    x_train, x_test, y_train, y_test = split_data(X.copy(), Y.copy())
    model = get_model()
    print("CNN model created successfully")
    model = train_model(model, x_train, y_train, x_test, y_test, 100, 20)
    print("CNN model trained successfully")
    save_model(model)
    print("CNN model saved successfully")
    print("End of process")
    return

# calling main function
run("Train_Data")
# Out:
# Starting process
# Data read successfully
# CNN model created successfully
# Epoch 1/20
# 116/116 [==============================] - 57s 473ms/step - loss: 0.7221 - accuracy: 0.7786 - val_loss: 0.2202 - val_accuracy: 0.9430
# Epoch 2/20
# 116/116 [==============================] - 59s 509ms/step - loss: 0.2105 - accuracy: 0.9370 - val_loss: 0.1221 - val_accuracy: 0.9648
# Epoch 3/20
# 116/116 [==============================] - 60s 520ms/step - loss: 0.1405 - accuracy: 0.9571 - val_loss: 0.0735 - val_accuracy: 0.9812
# Epoch 4/20
# 116/116 [==============================] - 61s 529ms/step - loss: 0.1043 - accuracy: 0.9688 - val_loss: 0.0843 - val_accuracy: 0.9781
# Epoch 5/20
# 116/116 [==============================] - 63s 539ms/step - loss: 0.0868 - accuracy: 0.9727 - val_loss: 0.0813 - val_accuracy: 0.9828
# Epoch 6/20
# 116/116 [==============================] - 63s 542ms/step - loss: 0.0688 - accuracy: 0.9788 - val_loss: 0.0659 - val_accuracy: 0.9867
# Epoch 7/20
# 116/116 [==============================] - 63s 543ms/step - loss: 0.0622 - accuracy: 0.9802 - val_loss: 0.0650 - val_accuracy: 0.9836
# Epoch 8/20
# 116/116 [==============================] - 67s 576ms/step - loss: 0.0554 - accuracy: 0.9813 - val_loss: 0.0862 - val_accuracy: 0.9820
# Epoch 9/20
# 116/116 [==============================] - 63s 548ms/step - loss: 0.0523 - accuracy: 0.9822 - val_loss: 0.0787 - val_accuracy: 0.9859
# Epoch 10/20
# 116/116 [==============================] - 68s 588ms/step - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.0739 - val_accuracy: 0.9859
# Epoch 11/20
# 116/116 [==============================] - 81s 700ms/step - loss: 0.0450 - accuracy: 0.9844 - val_loss: 0.0814 - val_accuracy: 0.9844
# Epoch 12/20
# 116/116 [==============================] - 78s 673ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.0814 - val_accuracy: 0.9844
# Epoch 13/20
# 116/116 [==============================] - 80s 690ms/step - loss: 0.0382 - accuracy: 0.9881 - val_loss: 0.0796 - val_accuracy: 0.9859
# Epoch 14/20
# 116/116 [==============================] - 69s 591ms/step - loss: 0.0378 - accuracy: 0.9879 - val_loss: 0.0848 - val_accuracy: 0.9867
# Epoch 15/20
# 116/116 [==============================] - 71s 612ms/step - loss: 0.0331 - accuracy: 0.9886 - val_loss: 0.0932 - val_accuracy: 0.9844
# Epoch 16/20
# 116/116 [==============================] - 74s 643ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.0663 - val_accuracy: 0.9867
# Epoch 17/20
# 116/116 [==============================] - 65s 563ms/step - loss: 0.0320 - accuracy: 0.9889 - val_loss: 0.0905 - val_accuracy: 0.9859
# Epoch 18/20
# 116/116 [==============================] - 65s 558ms/step - loss: 0.0338 - accuracy: 0.9886 - val_loss: 0.0941 - val_accuracy: 0.9844
# Epoch 19/20
# 116/116 [==============================] - 68s 584ms/step - loss: 0.0307 - accuracy: 0.9896 - val_loss: 0.0876 - val_accuracy: 0.9867
# Epoch 20/20
# 116/116 [==============================] - 71s 616ms/step - loss: 0.0296 - accuracy: 0.9885 - val_loss: 0.0856 - val_accuracy: 0.9844
# CNN model trained successfully
# CNN model saved successfully
# End of process
